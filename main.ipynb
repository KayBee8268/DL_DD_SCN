# %%
import os
import sys
import cv2
import time
import random
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from keras.models import model_from_json
import shutil
from utils import load_img, gen_x_y, eval_loss, gen_paths, ssim_eucli_loss, random_cropping, local_sum_loss, fix_singular_shape

# def save_mod(model , str1 , str2):
#     model.save_weights(str1)
    
#     model_json = model.to_json()
    
#     with open(str2, "w") as json_file:
#         json_file.write(model_json)


# Settings
dataset = "A"
rand_crop = True
# %matplotlib inline

img_paths_val, img_paths_train = gen_paths(
    path_file_root='data/paths_train_val_test',
    dataset=dataset
)
img_paths_val = sorted(img_paths_val, key=lambda x: int(x.split('_')[-1].split('.')[0]))
# print(img_paths_val)
x_val, y_val, img_paths_val = gen_x_y(img_paths_val[:], 'test')
print('Validation data size:', len(x_val), len(y_val), len(img_paths_val))
x_train, y_train, img_paths_train = gen_x_y(img_paths_train[:], 'train', augmentation_methods=['ori', 'flip'])
print('Train data size:', len(x_train), len(y_train), len(img_paths_train))
weights_dir = 'weights_' + dataset
if os.path.exists(weights_dir):
    shutil.rmtree(weights_dir)
# Out:
# C:\Users\asus\anaconda3\envs\csrnet_kb\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\asus\anaconda3\envs\csrnet_kb\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\asus\anaconda3\envs\csrnet_kb\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\asus\anaconda3\envs\csrnet_kb\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\asus\anaconda3\envs\csrnet_kb\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\asus\anaconda3\envs\csrnet_kb\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\asus\anaconda3\envs\csrnet_kb\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\asus\anaconda3\envs\csrnet_kb\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\asus\anaconda3\envs\csrnet_kb\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\asus\anaconda3\envs\csrnet_kb\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\asus\anaconda3\envs\csrnet_kb\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\asus\anaconda3\envs\csrnet_kb\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.
# ['paths_test.txt', 'paths_train.txt']
# Validation data size: 10 10 10
# Train data size: 50 50 25

# %%
import os
import shutil
from keras.optimizers import Adam
from utils import ssim_eucli_loss
from DD_SCN import DD_SCN


# Settings
weights_dir = 'weights_' + dataset
if os.path.exists(weights_dir):
    shutil.rmtree(weights_dir)
os.makedirs(weights_dir)
net = 'DD_SCN'
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
LOSS = 'ssim_eucli_loss'
lr = 1e-4
input_shape = (None, None, 3)#np.array((768, 1024, 3), dtype=int).tolist()

model = DD_SCN(input_shape=input_shape, IN=False)
model.summary()
optimizer = Adam(lr=lr)
model.compile(optimizer=optimizer, loss=ssim_eucli_loss)
from keras.utils import plot_model
plot_model(model, 'models/{}.png'.format(net))
# Out:
# WARNING:tensorflow:From C:\Users\asus\anaconda3\envs\csrnet_kb\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\asus\anaconda3\envs\csrnet_kb\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\asus\anaconda3\envs\csrnet_kb\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\Users\asus\anaconda3\envs\csrnet_kb\lib\site-packages\keras\backend\tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, None, None, 3 128         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, None, None, 3 128         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, None, None, 3 128         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, None, None, 3 128         input_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, None, None, 3 0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, None, None, 3 0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, None, None, 3 0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, None, None, 3 0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, None, None, 1 64          input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, None, None, 1 4624        activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, None, None, 1 12816       activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, None, None, 1 25104       activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, None, None, 1 25104       activation_8[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, None, None, 1 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, None, None, 1 0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, None, None, 1 0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, None, None, 1 0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, None, None, 1 0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, None, None, 8 0           activation_1[0][0]
#                                                                  activation_3[0][0]
#                                                                  activation_5[0][0]
#                                                                  activation_7[0][0]
#                                                                  activation_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, None, None, 8 0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, None, None, 6 5184        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, None, None, 6 5184        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, None, None, 6 5184        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, None, None, 6 5184        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, None, None, 6 0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, None, None, 6 0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, None, None, 6 0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, None, None, 6 0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, None, None, 3 2592        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, None, None, 3 18464       activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, None, None, 3 51232       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, None, None, 3 100384      activation_15[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, None, None, 3 100384      activation_17[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, None, None, 3 0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, None, None, 3 0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, None, None, 3 0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, None, None, 3 0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, None, None, 3 0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, None, None, 1 0           activation_10[0][0]
#                                                                  activation_12[0][0]
#                                                                  activation_14[0][0]
#                                                                  activation_16[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, None, None, 1 0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, None, None, 6 10304       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, None, None, 6 10304       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, None, None, 6 10304       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, None, None, 6 0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, None, None, 6 0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, None, None, 6 0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, None, None, 3 5152        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, None, None, 3 18464       activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, None, None, 3 51232       activation_22[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, None, None, 3 100384      activation_24[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, None, None, 3 0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, None, None, 3 0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, None, None, 3 0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, None, None, 3 0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, None, None, 1 0           activation_19[0][0]
#                                                                  activation_21[0][0]
#                                                                  activation_23[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, None, None, 1 0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, None, None, 6 8256        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, None, None, 6 8256        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, None, None, 6 8256        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, None, None, 6 0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, None, None, 6 0           conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, None, None, 6 0           conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, None, None, 3 4128        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, None, None, 3 18464       activation_27[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, None, None, 3 51232       activation_28[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, None, None, 3 100384      activation_29[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, None, None, 3 0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, None, None, 1 528         conv2d_28[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, None, None, 1 528         conv2d_30[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, None, None, 1 528         conv2d_32[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, None, None, 8 0           activation_26[0][0]
#                                                                  dense_1[0][0]
#                                                                  dense_2[0][0]
#                                                                  dense_3[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, None, None, 6 414784      concatenate_4[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, None, None, 6 0           conv2d_33[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, None, None, 6 16448       activation_30[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, None, None, 6 0           conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, None, None, 3 100384      activation_31[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, None, None, 3 0           conv2d_34[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, None, None, 3 4128        activation_32[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, None, None, 3 0           conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, None, None, 1 12816       activation_33[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, None, None, 1 0           conv2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, None, None, 1 1040        activation_34[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, None, None, 1 272         conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, None, None, 1 2320        dense_4[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, None, None, 1 0           conv2d_36[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, None, None, 1 6416        activation_35[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, None, None, 1 0           conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, None, None, 1 17          activation_36[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, None, None, 1 0           conv2d_38[0][0]
# ==================================================================================================
# Total params: 1,327,345
# Trainable params: 1,327,345
# Non-trainable params: 0
# __________________________________________________________________________________________________
# WARNING:tensorflow:From C:\Users\asus\anaconda3\envs\csrnet_kb\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# Settings
lossMAE = 1e5
lossMDMD, lossMAPE, lossMSE = -1, -1, -1
counter_train = 0
mae = 1e5
mdmd = 1e5
val_rate = 0.25
lossesMDMD = []
lossesMAE = []
lossesMAPE = []
lossesMSE = []
path_val_display = img_paths_val[0]
x_val_display = load_img(path_val_display)
y_val_display = np.squeeze(y_val[0])
x_val_display, y_val_display = fix_singular_shape(x_val_display), fix_singular_shape(y_val_display)
with open('./models/{}.json'.format(net), 'w') as fout:
    fout.write(model.to_json())
if dataset == 'A':
    save_frequencies = [(90, 0.1), (80, 0.05), (95, 0.25)]
else:
    save_frequencies = [(20, 0.1), (15, 0.05), (22, 0.25)]
# epoch_train = 100

# Set differernt modules trainable 3 Inception-like module and the Decoder module trainable seperatly.
branches_trainable = [
    list(range(1, 7+1)),
    list(range(8, 14+1)),
    list(range(15, 21+1)),
    list(range(22, 28+1)),
    list(range(29, 34+1))
]
if_train_seperatly = True
if if_train_seperatly:
    module_step = 40
    epoch_train_seperatly = module_step * len(branches_trainable) * 1
    epoch_train = 5
else:
    epoch_train = 5

# Training
time_st = time.time()
for epoch in range(epoch_train):
    if if_train_seperatly:
        trainable_choice = int(epoch/module_step) # epoch % (5*len(branches_trainable))
        print('trainable_choice:', trainable_choice)
        # Train modules seperatly to avoid output all zeros
        if epoch < epoch_train_seperatly and trainable_choice in list(range(len(branches_trainable))):# [0, module_step*1, module_step*2, module_step*3, module_step*4, module_step*5]:
            branch_trainable = branches_trainable[trainable_choice]
            for i in range(1, len(model.layers)):
                if 'conv' in model.layers[i].name:
                    model.layers[i].trainable = False
            for i in range(1, len(model.layers)):
                idx_operator = int(model.layers[i].name.split('_')[-1])
                if 'conv' in model.layers[i].name and idx_operator in branch_trainable:
                    model.layers[i].trainable = True
            model.compile(optimizer=Adam(lr=lr), loss=ssim_eucli_loss)
        elif epoch == epoch_train_seperatly:
            for i in range(1, len(model.layers)):
                model.layers[i].trainable = True
            model.compile(optimizer=Adam(lr=lr/1), loss=ssim_eucli_loss)
        else:
            pass

#     if epoch == 35:
#         for i in range(1, 14):
#         #     print(model.layers[i].name)
#             model.layers[i].trainable = True
#         optimizer = Adam(lr=lr/10)
#         model.compile(optimizer=optimizer, loss=local_sum_loss)
    for i in range(len(x_train)):
        if lossMAE < save_frequencies[0][0]:
            val_rate = save_frequencies[0][1]
            if lossMAE < save_frequencies[1][0]:
                val_rate = save_frequencies[1][1]
        if len(lossesMAE) > 100 and val_rate <= save_frequencies[-1][-1] and np.median(lossesMAE[-20]) > save_frequencies[-1][0]:
            val_rate = save_frequencies[-1][-1]
        x_, y_ = x_train[i], y_train[i]
        model.fit(x_, y_, verbose=0)
#         x_cropped, y_cropped = random_cropping(x_, y_)
#         for idx_fit in range(x_cropped.shape[0]):
#             model.fit(x_cropped[idx_fit:idx_fit+1], y_cropped[idx_fit:idx_fit+1], verbose=0)
        counter_train += 1
#         if epoch < 5:
#             val_rate = 0.1
        if counter_train % int(len(x_train)*val_rate) == 0:
            # Calc loss
            lossMDMD, lossMAE, lossMAPE, lossMSE = eval_loss(model, x_val, y_val)
            lossesMDMD.append(lossMDMD)
            lossesMAE.append(lossMAE)
            lossesMAPE.append(lossMAPE)
            lossesMSE.append(lossMSE)
            lossMAE, lossMAPE, lossMDMD, lossMSE = round(lossMAE, 3), round(lossMAPE, 3), round(lossMDMD, 3), round(lossMSE, 3)
            if ((lossMAE < mae or lossMDMD < mdmd) and epoch >= 0) or lossMAE < save_frequencies[1][0] * 0.9:
                model.save_weights(
                    os.path.join(weights_dir, '{}_MAE{}_MSE{}_MAPE{}_MDMD{}_epoch{}-{}.hdf5'.format(
                        net, str(lossMAE), str(lossMSE), str(lossMAPE), str(lossMDMD), epoch, (counter_train-1)%len(x_train)
                    ))
                )
                if lossMAE < mae:
                    mae = lossMAE
                    model.save_weights(os.path.join(weights_dir, '{}_best.hdf5'.format(net)))
                if lossMDMD < mdmd:
                    mdmd = lossMDMD
            if counter_train % (len(x_train)*1) == 0:
                # show prediction
                pred = np.squeeze(model.predict(np.expand_dims(x_val_display, axis=0)))
                fg, (ax_x_ori, ax_y, ax_pred) = plt.subplots(1, 3, figsize=(20, 4))
                ax_x_ori.imshow(cv2.cvtColor(cv2.imread(path_val_display), cv2.COLOR_BGR2RGB))
                ax_x_ori.set_title('Original Image')
                ax_y.imshow(y_val_display, cmap=plt.cm.jet)
                ax_y.set_title('Ground_truth: ' + str(np.sum(y_val_display)))
                ax_pred.imshow(pred, cmap=plt.cm.jet)
                ax_pred.set_title('Prediction: ' + str(np.sum(pred)))
                plt.suptitle('Loss = ' + str(lossMAE))
                plt.show()
                if counter_train % (len(x_train)*4) == 0 or (epoch+1) % (20) == 0:
                    # plot val_loss
                    plt.plot(lossesMAPE, 'y')
                    plt.plot(lossesMAE, 'b')
                    plt.plot(lossesMSE, 'c')
                    plt.plot(lossesMDMD, 'r')
                    plt.legend(['LossMAPE', 'LossMAE', 'LossMSE', 'Loss_Density_Map_Distance'])
                    plt.title('Loss')
                    plt.show()
        time_now = time.time()
        time_consuming = time_now - time_st
        sys.stdout.write('In epoch {}_{}, with MAE={}, MSE={}, MAPE={}, MDMD={}, time consuming={}m-{}s\r'.format(
            epoch, counter_train%len(x_train), str(lossMAE), str(lossMSE), str(lossMAPE), str(lossMDMD),
            int(time_consuming/60), int(time_consuming-int(time_consuming/60)*60)
        ))
        sys.stdout.flush()
end_time_of_train = '-'.join(time.ctime().split()[:-2])
suffix_new_dir = '_{}_{}_bestMAE{}_{}'.format(dataset, LOSS, str(round(mae, 3)), end_time_of_train)
shutil.move('weights_{}'.format(dataset), 'weights'+suffix_new_dir)

loss_dir = 'losses_' + dataset
if not os.path.exists(loss_dir):
    os.makedirs(loss_dir)
np.savetxt(os.path.join(loss_dir, 'loss_DMD.txt'), lossesMDMD)
np.savetxt(os.path.join(loss_dir, 'loss_MAE.txt'), lossesMAE)
np.savetxt(os.path.join(loss_dir, 'loss_MAPE.txt'), lossesMAPE)
np.savetxt(os.path.join(loss_dir, 'loss_MSE.txt'), lossesMSE)
plt.plot(lossesMAPE, 'y')
plt.plot(lossesMAE, 'b')
plt.plot(lossesMSE, 'c')
plt.plot(lossesMDMD, 'r')
plt.legend(['LossMAPE', 'LossMAE', 'LossMSE', 'Loss_Density_Map_Distance'])
plt.title('Loss -- {} epochs'.format(epoch_train))
plt.savefig('./losses_{}/loss_{}_{}.jpg'.format(dataset, dataset, end_time_of_train))
plt.show()
shutil.move('losses_{}'.format(dataset), 'losses'+suffix_new_dir)


# keras.models.save_model(model,"models/ModelA")
# Out:
# trainable_choice: 0
# WARNING:tensorflow:From C:\Users\asus\anaconda3\envs\csrnet_kb\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From C:\Users\asus\anaconda3\envs\csrnet_kb\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# trainable_choice: 0MAE=496.067, MSE=615.583, MAPE=0.828, MDMD=843.518, time consuming=3m-42ss
# trainable_choice: 0MAE=461.465, MSE=582.571, MAPE=0.749, MDMD=842.691, time consuming=4m-24ss
# trainable_choice: 0MAE=414.497, MSE=540.769, MAPE=0.64, MDMD=838.326, time consuming=5m-7ssss
# trainable_choice: 0MAE=364.525, MSE=483.375, MAPE=0.576, MDMD=834.15, time consuming=5m-51sss
# In epoch 4_0, with MAE=332.9, MSE=453.151, MAPE=0.528, MDMD=831.941, time consuming=6m-33ssss
# 'losses_A_ssim_eucli_loss_bestMAE331.377_Mon-Apr-24'

# %%
dataset = "B"
rand_crop = True
# %matplotlib inline

img_paths_val, img_paths_train = gen_paths(
    path_file_root='data/paths_train_val_test',
    dataset=dataset
)
img_paths_val = sorted(img_paths_val, key=lambda x: int(x.split('_')[-1].split('.')[0]))
# print(img_paths_val)
x_val, y_val, img_paths_val = gen_x_y(img_paths_val[:], 'test')
print('Validation data size:', len(x_val), len(y_val), len(img_paths_val))
x_train, y_train, img_paths_train = gen_x_y(img_paths_train[:], 'train', augmentation_methods=['ori', 'flip'])
print('Train data size:', len(x_train), len(y_train), len(img_paths_train))
weights_dir = 'weights_' + dataset
if os.path.exists(weights_dir):
    shutil.rmtree(weights_dir)
# Out:
# ['paths_test.txt', 'paths_train.txt']
# Validation data size: 10 10 10
# Train data size: 50 50 25

# %%
import os
import shutil
from keras.optimizers import Adam
from utils import ssim_eucli_loss
from DD_SCN import DD_SCN


# Settings
weights_dir = 'weights_' + dataset
if os.path.exists(weights_dir):
    shutil.rmtree(weights_dir)
os.makedirs(weights_dir)
net = 'DD_SCN'
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
LOSS = 'ssim_eucli_loss'
lr = 1e-4
input_shape = (None, None, 3)#np.array((768, 1024, 3), dtype=int).tolist()

model = DD_SCN(input_shape=input_shape, IN=False)
model.summary()
optimizer = Adam(lr=lr)
model.compile(optimizer=optimizer, loss=ssim_eucli_loss)
from keras.utils import plot_model
plot_model(model, 'models/{}.png'.format(net))
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, None, None, 3 128         input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, None, None, 3 128         input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, None, None, 3 128         input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, None, None, 3 128         input_2[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, None, None, 3 0           conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, None, None, 3 0           conv2d_42[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, None, None, 3 0           conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, None, None, 3 0           conv2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, None, None, 1 64          input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, None, None, 1 4624        activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, None, None, 1 12816       activation_41[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, None, None, 1 25104       activation_43[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, None, None, 1 25104       activation_45[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, None, None, 1 0           conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, None, None, 1 0           conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, None, None, 1 0           conv2d_43[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, None, None, 1 0           conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, None, None, 1 0           conv2d_47[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, None, None, 8 0           activation_38[0][0]
#                                                                  activation_40[0][0]
#                                                                  activation_42[0][0]
#                                                                  activation_44[0][0]
#                                                                  activation_46[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, None, None, 8 0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, None, None, 6 5184        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, None, None, 6 5184        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, None, None, 6 5184        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, None, None, 6 5184        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, None, None, 6 0           conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, None, None, 6 0           conv2d_51[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, None, None, 6 0           conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, None, None, 6 0           conv2d_55[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, None, None, 3 2592        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, None, None, 3 18464       activation_48[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, None, None, 3 51232       activation_50[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, None, None, 3 100384      activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, None, None, 3 100384      activation_54[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, None, None, 3 0           conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, None, None, 3 0           conv2d_50[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, None, None, 3 0           conv2d_52[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, None, None, 3 0           conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, None, None, 3 0           conv2d_56[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, None, None, 1 0           activation_47[0][0]
#                                                                  activation_49[0][0]
#                                                                  activation_51[0][0]
#                                                                  activation_53[0][0]
#                                                                  activation_55[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, None, None, 1 0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, None, None, 6 10304       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, None, None, 6 10304       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, None, None, 6 10304       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, None, None, 6 0           conv2d_58[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, None, None, 6 0           conv2d_60[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, None, None, 6 0           conv2d_62[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, None, None, 3 5152        max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, None, None, 3 18464       activation_57[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, None, None, 3 51232       activation_59[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, None, None, 3 100384      activation_61[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, None, None, 3 0           conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, None, None, 3 0           conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, None, None, 3 0           conv2d_61[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, None, None, 3 0           conv2d_63[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, None, None, 1 0           activation_56[0][0]
#                                                                  activation_58[0][0]
#                                                                  activation_60[0][0]
#                                                                  activation_62[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, None, None, 1 0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, None, None, 6 8256        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, None, None, 6 8256        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, None, None, 6 8256        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, None, None, 6 0           conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, None, None, 6 0           conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, None, None, 6 0           conv2d_69[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, None, None, 3 4128        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, None, None, 3 18464       activation_64[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, None, None, 3 51232       activation_65[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, None, None, 3 100384      activation_66[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, None, None, 3 0           conv2d_64[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, None, None, 1 528         conv2d_66[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, None, None, 1 528         conv2d_68[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, None, None, 1 528         conv2d_70[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, None, None, 8 0           activation_63[0][0]
#                                                                  dense_5[0][0]
#                                                                  dense_6[0][0]
#                                                                  dense_7[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, None, None, 6 414784      concatenate_8[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, None, None, 6 0           conv2d_71[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, None, None, 6 16448       activation_67[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, None, None, 6 0           conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, None, None, 3 100384      activation_68[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, None, None, 3 0           conv2d_72[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, None, None, 3 4128        activation_69[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, None, None, 3 0           conv2d_transpose_5[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, None, None, 1 12816       activation_70[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, None, None, 1 0           conv2d_73[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, None, None, 1 1040        activation_71[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, None, None, 1 272         conv2d_transpose_6[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, None, None, 1 2320        dense_8[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, None, None, 1 0           conv2d_74[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, None, None, 1 6416        activation_72[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, None, None, 1 0           conv2d_75[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, None, None, 1 17          activation_73[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, None, None, 1 0           conv2d_76[0][0]
# ==================================================================================================
# Total params: 1,327,345
# Trainable params: 1,327,345
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Settings
lossMAE = 1e5
lossMDMD, lossMAPE, lossMSE = -1, -1, -1
counter_train = 0
mae = 1e5
mdmd = 1e5
val_rate = 0.25
lossesMDMD = []
lossesMAE = []
lossesMAPE = []
lossesMSE = []
path_val_display = img_paths_val[0]
x_val_display = load_img(path_val_display)
y_val_display = np.squeeze(y_val[0])
x_val_display, y_val_display = fix_singular_shape(x_val_display), fix_singular_shape(y_val_display)
with open('./models/{}.json'.format(net), 'w') as fout:
    fout.write(model.to_json())
if dataset == 'A':
    save_frequencies = [(90, 0.1), (80, 0.05), (95, 0.25)]
else:
    save_frequencies = [(20, 0.1), (15, 0.05), (22, 0.25)]
# epoch_train = 100

# Set differernt modules trainable 3 Inception-like module and the Decoder module trainable seperatly.
branches_trainable = [
    list(range(1, 7+1)),
    list(range(8, 14+1)),
    list(range(15, 21+1)),
    list(range(22, 28+1)),
    list(range(29, 34+1))
]
if_train_seperatly = True
if if_train_seperatly:
    module_step = 40
    epoch_train_seperatly = module_step * len(branches_trainable) * 1
    epoch_train = 5
else:
    epoch_train = 5

# Training
time_st = time.time()
for epoch in range(epoch_train):
    if if_train_seperatly:
        trainable_choice = int(epoch/module_step) # epoch % (5*len(branches_trainable))
        print('trainable_choice:', trainable_choice)
        # Train modules seperatly to avoid output all zeros
        if epoch < epoch_train_seperatly and trainable_choice in list(range(len(branches_trainable))):# [0, module_step*1, module_step*2, module_step*3, module_step*4, module_step*5]:
            branch_trainable = branches_trainable[trainable_choice]
            for i in range(1, len(model.layers)):
                if 'conv' in model.layers[i].name:
                    model.layers[i].trainable = False
            for i in range(1, len(model.layers)):
                idx_operator = int(model.layers[i].name.split('_')[-1])
                if 'conv' in model.layers[i].name and idx_operator in branch_trainable:
                    model.layers[i].trainable = True
            model.compile(optimizer=Adam(lr=lr), loss=ssim_eucli_loss)
        elif epoch == epoch_train_seperatly:
            for i in range(1, len(model.layers)):
                model.layers[i].trainable = True
            model.compile(optimizer=Adam(lr=lr/1), loss=ssim_eucli_loss)
        else:
            pass

#     if epoch == 35:
#         for i in range(1, 14):
#         #     print(model.layers[i].name)
#             model.layers[i].trainable = True
#         optimizer = Adam(lr=lr/10)
#         model.compile(optimizer=optimizer, loss=local_sum_loss)
    for i in range(len(x_train)):
        if lossMAE < save_frequencies[0][0]:
            val_rate = save_frequencies[0][1]
            if lossMAE < save_frequencies[1][0]:
                val_rate = save_frequencies[1][1]
        if len(lossesMAE) > 100 and val_rate <= save_frequencies[-1][-1] and np.median(lossesMAE[-20]) > save_frequencies[-1][0]:
            val_rate = save_frequencies[-1][-1]
        x_, y_ = x_train[i], y_train[i]
        model.fit(x_, y_, verbose=0)
#         x_cropped, y_cropped = random_cropping(x_, y_)
#         for idx_fit in range(x_cropped.shape[0]):
#             model.fit(x_cropped[idx_fit:idx_fit+1], y_cropped[idx_fit:idx_fit+1], verbose=0)
        counter_train += 1
#         if epoch < 5:
#             val_rate = 0.1
        if counter_train % int(len(x_train)*val_rate) == 0:
            # Calc loss
            lossMDMD, lossMAE, lossMAPE, lossMSE = eval_loss(model, x_val, y_val)
            lossesMDMD.append(lossMDMD)
            lossesMAE.append(lossMAE)
            lossesMAPE.append(lossMAPE)
            lossesMSE.append(lossMSE)
            lossMAE, lossMAPE, lossMDMD, lossMSE = round(lossMAE, 3), round(lossMAPE, 3), round(lossMDMD, 3), round(lossMSE, 3)
            if ((lossMAE < mae or lossMDMD < mdmd) and epoch >= 0) or lossMAE < save_frequencies[1][0] * 0.9:
                model.save_weights(
                    os.path.join(weights_dir, '{}_MAE{}_MSE{}_MAPE{}_MDMD{}_epoch{}-{}.hdf5'.format(
                        net, str(lossMAE), str(lossMSE), str(lossMAPE), str(lossMDMD), epoch, (counter_train-1)%len(x_train)
                    ))
                )
                if lossMAE < mae:
                    mae = lossMAE
                    model.save_weights(os.path.join(weights_dir, '{}_best.hdf5'.format(net)))
                if lossMDMD < mdmd:
                    mdmd = lossMDMD
            if counter_train % (len(x_train)*1) == 0:
                # show prediction
                pred = np.squeeze(model.predict(np.expand_dims(x_val_display, axis=0)))
                fg, (ax_x_ori, ax_y, ax_pred) = plt.subplots(1, 3, figsize=(20, 4))
                ax_x_ori.imshow(cv2.cvtColor(cv2.imread(path_val_display), cv2.COLOR_BGR2RGB))
                ax_x_ori.set_title('Original Image')
                ax_y.imshow(y_val_display, cmap=plt.cm.jet)
                ax_y.set_title('Ground_truth: ' + str(np.sum(y_val_display)))
                ax_pred.imshow(pred, cmap=plt.cm.jet)
                ax_pred.set_title('Prediction: ' + str(np.sum(pred)))
                plt.suptitle('Loss = ' + str(lossMAE))
                plt.show()
                if counter_train % (len(x_train)*4) == 0 or (epoch+1) % (20) == 0:
                    # plot val_loss
                    plt.plot(lossesMAPE, 'y')
                    plt.plot(lossesMAE, 'b')
                    plt.plot(lossesMSE, 'c')
                    plt.plot(lossesMDMD, 'r')
                    plt.legend(['LossMAPE', 'LossMAE', 'LossMSE', 'Loss_Density_Map_Distance'])
                    plt.title('Loss')
                    plt.show()
        time_now = time.time()
        time_consuming = time_now - time_st
        sys.stdout.write('In epoch {}_{}, with MAE={}, MSE={}, MAPE={}, MDMD={}, time consuming={}m-{}s\r'.format(
            epoch, counter_train%len(x_train), str(lossMAE), str(lossMSE), str(lossMAPE), str(lossMDMD),
            int(time_consuming/60), int(time_consuming-int(time_consuming/60)*60)
        ))
        sys.stdout.flush()
end_time_of_train = '-'.join(time.ctime().split()[:-2])
suffix_new_dir = '_{}_{}_bestMAE{}_{}'.format(dataset, LOSS, str(round(mae, 3)), end_time_of_train)
shutil.move('weights_{}'.format(dataset), 'weights'+suffix_new_dir)

loss_dir = 'losses_' + dataset
if not os.path.exists(loss_dir):
    os.makedirs(loss_dir)
np.savetxt(os.path.join(loss_dir, 'loss_DMD.txt'), lossesMDMD)
np.savetxt(os.path.join(loss_dir, 'loss_MAE.txt'), lossesMAE)
np.savetxt(os.path.join(loss_dir, 'loss_MAPE.txt'), lossesMAPE)
np.savetxt(os.path.join(loss_dir, 'loss_MSE.txt'), lossesMSE)
plt.plot(lossesMAPE, 'y')
plt.plot(lossesMAE, 'b')
plt.plot(lossesMSE, 'c')
plt.plot(lossesMDMD, 'r')
plt.legend(['LossMAPE', 'LossMAE', 'LossMSE', 'Loss_Density_Map_Distance'])
plt.title('Loss -- {} epochs'.format(epoch_train))
plt.savefig('./losses_{}/loss_{}_{}.jpg'.format(dataset, dataset, end_time_of_train))
plt.show()
shutil.move('losses_{}'.format(dataset), 'losses'+suffix_new_dir)


# keras.models.save_model(model,"models/ModelB")
# Out:
# trainable_choice: 0
# trainable_choice: 0MAE=53.236, MSE=57.843, MAPE=0.98, MDMD=10.464, time consuming=0m-42ss
# trainable_choice: 0MAE=54.899, MSE=59.172, MAPE=1.021, MDMD=10.086, time consuming=1m-17ss
# trainable_choice: 0MAE=40.927, MSE=52.216, MAPE=0.664, MDMD=9.15, time consuming=1m-53ssss
# trainable_choice: 0MAE=38.102, MSE=54.741, MAPE=0.488, MDMD=8.575, time consuming=2m-29sss
# In epoch 4_0, with MAE=39.096, MSE=56.545, MAPE=0.468, MDMD=8.336, time consuming=3m-4ss
# 'losses_B_ssim_eucli_loss_bestMAE38.102_Mon-Apr-24'
